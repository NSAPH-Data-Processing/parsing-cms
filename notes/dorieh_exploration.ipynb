# %%
# import necessary part of dorieh python package 
from dorieh.cms.fts2yaml import MedicareFTS, mcr_type
import os

# %%
CURR_DIR = "/n/dominici_nsaph_l3/Lab/data/ci3_d_medicare/original_data/cms_medicare/data/4580/2013/"
fname_orig = CURR_DIR + "medpar_all_file_res000017155_req004580_2013.fts"

# %%
# what is the *type* of this medicare file? medpar
basedir, fname = os.path.split(fname_orig)
t = mcr_type(fname)
print(t)

# loading fts file as a 'MedicareFTS' object
fts = MedicareFTS(t).init(fname_orig)
# MedicareFTS --> dictionary 
fts_dict = fts.to_dict()
